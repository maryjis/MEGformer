# %%
import seaborn as sns
import pandas as pd

# %%
sns.set_style('ticks')
# plt.rcParams.update({'font.size': 8})

# %%
d = {'segment length': [3, 4, 7,3,4,7], 'WER top-10': [1-0.438, 1-0.296, 1-0.127, 1-0.50, 1-0.42,1-0.33], 'dataset' : ['Gwilliams', 'Gwilliams', 'Gwilliams' , 'Schoffelen', 'Schoffelen', 'Schoffelen']}
df = pd.DataFrame(data=d)

# %%
sns.lineplot(x="segment length", y="WER top-10", hue="dataset", style="dataset", color=['salmon', 'teal'], markers=['o', 'o'], data=df).figure.savefig("increasing_dataset.png")
